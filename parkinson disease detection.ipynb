# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv(r"C:\Users\Jayasuriya\Downloads\parkinsons.csv")
data
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
data.isna().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
data.shape
# Out:
# (195, 24)

# %%
#1 represents person has parkinson's disease
#0 represnts person who does not have parkinson's disease

# %%
data['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
data.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
x=data.drop(columns=['name','status'],axis=1)

# %%
y=data['status']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
X_train,X_test,Y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 42       237.226       247.326       225.227         0.00298
# 17       168.778       232.181        75.603         0.00718
# 5        120.552       131.162       113.787         0.00968
# 120      128.940       479.697        88.251         0.00581
# 98       125.791       140.557        96.206         0.01378
# ..           ...           ...           ...             ...
# 133      118.747       123.723       109.836         0.00331
# 137      113.166       130.270       100.673         0.00502
# 72       120.080       139.710       111.208         0.00405
# 140      170.368       268.796        79.543         0.00571
# 37       176.170       185.604       163.564         0.00369
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 42            0.00001   0.00169   0.00182     0.00507       0.01752
# 17            0.00004   0.00284   0.00387     0.00853       0.03327
# ...

# %%
X_test
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 132      119.056       125.213        86.795         0.00346
# 16       144.188       349.259        82.764         0.00544
# 18       153.046       175.829        68.623         0.00742
# 51       126.344       134.231       112.773         0.00448
# 164      102.273       142.830        85.902         0.00907
# 145      223.361       263.872        87.638         0.00352
# 11        91.904       115.871        86.292         0.00540
# 27       146.845       208.701        81.737         0.00496
# 176      116.388       129.038       108.970         0.00346
# 118      178.285       442.824        82.063         0.00462
# 28       155.358       227.383        80.055         0.00310
# 170      244.990       272.210       239.170         0.00451
# 56       110.417       131.067       103.370         0.00784
# 116      158.219       442.557        71.948         0.00476
# ...

# %%
Y_train
# Out:
# 42     0
# 17     1
# 5      1
# 120    1
# 98     1
#       ..
# 133    1
# 137    1
# 72     1
# 140    1
# 37     1
# Name: status, Length: 136, dtype: int64

# %%
y_test
# Out:
# 132    1
# 16     1
# 18     1
# 51     0
# 164    1
# 145    1
# 11     1
# 27     1
# 176    0
# 118    1
# 28     1
# 170    0
# 56     1
# 116    1
# 103    1
# 31     0
# 59     1
# 40     1
# 136    1
# 95     1
# 35     0
# 107    1
# 69     1
# 84     1
# 130    1
# 99     1
# 123    1
# 29     1
# 4      1
# 167    0
# 82     1
# 188    0
# 67     1
# 190    0
# 81     1
# 112    1
# 44     0
# 181    1
# 187    0
# 53     0
# 14     1
# 119    1
# 19     1
# 47     0
# 39     1
# 94     1
# 117    1
# 90     1
# 66     1
# 58     1
# 33     0
# 175    0
# 153    1
# 189    0
# 194    0
# 185    0
# 193    0
# 168    0
# 73     1
# Name: status, dtype: int64

# %%
ss=StandardScaler()
X_train=ss.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 2.07198653,  0.70468294,  2.53168424, ..., -1.50340206,
#          0.05817082, -1.27152628],
#        [ 0.39318622,  0.52183306, -1.01737916, ...,  2.4793937 ,
#          1.57297492,  2.42332906],
#        [-0.78963612, -0.69779797, -0.11165924, ...,  0.87507728,
#         -0.5298694 ,  1.61985132],
#        ...,
#        [-0.8012127 , -0.59459554, -0.17283282, ...,  1.23049124,
#         -0.48507865, -0.24647122],
#        [ 0.4321836 ,  0.96389633, -0.92392283, ...,  2.04541018,
#          1.46098777,  0.73345403],
#        [ 0.57448724, -0.04050427,  1.06904525, ..., -0.34392557,
#          0.3651429 , -0.41112182]])

# %%
X_test=ss.transform(X_test)
X_test
# Out:
# array([[-0.82632799, -0.76962193, -0.75190626, ...,  0.35062367,
#          0.31331705,  0.23804964],
#        [-0.20992416,  1.93534894, -0.8475211 , ...,  0.17092931,
#         -0.33253515,  0.08349025],
#        [ 0.00733293, -0.15852061, -1.18294393, ...,  1.57224866,
#          1.83341735,  1.83613543],
#        ...,
#        [ 1.12864243,  2.51126871, -1.03395936, ..., -0.21242655,
#         -0.65541893, -0.96038265],
#        [ 1.09933308,  0.34611849, -0.65705046, ..., -0.72172865,
#          1.25234812, -0.08471483],
#        [-0.99904468,  4.82399067, -0.2720768 , ...,  0.96436087,
#         -1.19375947,  0.1637907 ]])

# %%
model=svm.SVC(kernel='linear')

# %%
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
#accuracy of training data
X_train_prediction=model.predict(X_train)
training_acc=accuracy_score(Y_train,X_train_prediction)

# %%
print('accuracy score of training data',training_acc)
# Out:
# accuracy score of training data 0.9264705882352942

# %%
X_test_prediction=model.predict(X_test)
test_acc=accuracy_score(y_test,X_test_prediction)

# %%
print('accuracy score of testing data',test_acc)
# Out:
# accuracy score of testing data 0.8305084745762712

# %%
 #BUILDING A PREDICTIVE SYSTEM

# %%
input_data=(142.16700,217.45500,83.15900,0.00369,0.00003,0.00157,0.00203,0.00471,0.01503,0.12600,0.00772,0.00888,0.01359,0.02316,0.00839,25.17500,0.565924,0.658245,-5.340115,0.210185,2.205546,0.234589)
input_data2=(203.18400,211.52600,196.16000,0.00178,0.000009,0.00094,0.00106,0.00283,0.00958,0.08500,0.00468,0.00610,0.00726,0.01403,0.00065,33.04700,0.340068,0.741899,-7.964984,0.163519,1.423287,0.044539)
#changing input data into numpy array
input_data_as_numpy_array=np.asarray(input_data2)
#reshape the num array
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
#standardize the data
std_data=ss.transform(input_data_reshaped)
prediction=model.predict(std_data)
print(prediction)
# Out:
# [0]
# C:\Users\Jayasuriya\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
